# %%
from sqlite3 import dbapi2 as sq3
from pathlib import Path
PATHSTART="."
def get_db(dbfile):
    sqlite_db = sq3.connect(Path(PATHSTART) / dbfile)
    return sqlite_db

# %%
def init_db(dbfile, schema):
    """Creates the database tables."""
    db = get_db(dbfile)
    db.cursor().executescript(schema)
    db.commit()
    return db

# %%
from collections import OrderedDict
import pandas as pd
def make_frame(list_of_tuples, legend):
    framelist=[]
    for i, cname in enumerate(legend):
        framelist.append((cname,[e[i] for e in list_of_tuples]))
    return pd.DataFrame.from_dict(OrderedDict(framelist))

# %%
def make_query(sel):
    c=db.cursor().execute(sel)
    return c.fetchall()

# %%
db=init_db("cancont.db", "")

# %%
candidate_cols = [e[1] for e in make_query("PRAGMA table_info(candidates);")]
candidate_cols
# Out:
# ['id', 'first_name', 'last_name', 'middle_name', 'party']

# %%
out=make_query("SELECT first_name, party FROM candidates;")
make_frame(out,['first_name', 'amount'])
# Out:
#      first_name amount
# 0          Mike      R
# 1        Barack      D
# 2       Rudolph      R
# 3          Mike      D
# 4          John      D
# 5          Bill      D
# 6        Duncan      R
# 7        Dennis      D
# 8           Ron      R
# 9        Joseph      D
# 10      Hillary      D
# 11         Mitt      R
# 12       Samuel      R
# 13         John      R
# 14          Tom      R
# 15  Christopher      D
# 16         Fred      R

# %%
contributor_cols = [e[1] for e in make_query("PRAGMA table_info(contributors);")]
contributor_cols
# Out:
# ['id',
#  'last_name',
#  'first_name',
#  'middle_name',
#  'street_1',
#  'street_2',
#  'city',
#  'state',
#  'zip',
#  'amount',
#  'date',
#  'candidate_id']

# %%
rem="""
DELETE FROM contributors;
"""
c=db.cursor().execute(rem)
db.commit()

# %%
ins="""
INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id) \
    VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
"""

# %%
slines[1]
# Out:
# ['',
#  'Agee',
#  'Steven',
#  '',
#  '549 Laurel Branch Road',
#  '',
#  'Floyd',
#  'VA',
#  '24091',
#  '500.00',
#  '2007-06-30',
#  '16']

# %%
from datetime import date

fd = open("data/contributors_with_candidate_id.txt")
slines =[l.strip().split('|') for l in fd.readlines()]
print(slines)
fd.close()
for list_from_line in slines[1:]:
    last_name, first_name, middle_name, street_1, street_2, city, state, zip_code, amount, c_date, candidate_id = list_from_line[1:]
    valstoinsert = (last_name, first_name, middle_name, street_1, street_2, city, state, zip_code, int(float(amount)), datetime.fromisoformat(c_date), int(candidate_id))
    print(ins, valstoinsert)
    db.cursor().execute(ins, valstoinsert)

db.commit()
# Out:
# [['id', 'last_name', 'first_name', 'middle_name', 'street_1', 'street_2', 'city', 'state', 'zip', 'amount', 'date', 'candidate_id'], ['', 'Agee', 'Steven', '', '549 Laurel Branch Road', '', 'Floyd', 'VA', '24091', '500.00', '2007-06-30', '16'], ['', 'Ahrens', 'Don', '', '4034 Rennellwood Way', '', 'Pleasanton', 'CA', '94566', '250.00', '2007-05-16', '16'], ['', 'Ahrens', 'Don', '', '4034 Rennellwood Way', '', 'Pleasanton', 'CA', '94566', '50.00', '2007-06-18', '16'], ['', 'Ahrens', 'Don', '', '4034 Rennellwood Way', '', 'Pleasanton', 'CA', '94566', '100.00', '2007-06-21', '16'], ['', 'Akin', 'Charles', '',
 'Buckel', 'Linda', '', 'PO Box 683130', '', 'Park City', 'UT', '840683130', '2300.00', '2007-08-14', '20'], ['', 'Buckel', 'Linda', '', 'PO Box 683130', '', 'Park City', 'UT', '840683130', '-2300.00', '2007-08-14', '20'], ['', 'Buckel', 'Linda', '', 'PO Box 683130', '', 'Park City', 'UT', '840683130', '4600.00', '2007-08-14', '20'], ['', 'Buck', 'Thomas', '', '4206 Terrace Street', '', 'Kansas City', 'MO', '64111', '100.00', '2007-09-25', '20'], ['', 'Buck', 'Jay', 'K.', '1855 Old Willow Rd Unit 322', '', 'Northfield', 'IL', '600932918', '200.00', '2007-09-12', '20'], ['', 'Buck', 'Blaine', 'M', '45 E ...
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Agee', 'Steven', '', '549 Laurel Branch Road', '', 'Floyd', 'VA', '24091', 500, datetime.datetime(2007, 6, 30, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Ahrens', 'Don', '', '4034 Rennellwood Way', '', 'Pleasanton', 'CA', '94566', 250, datetime.datetime(2007, 5, 16, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Ahrens', 'Don', '', '4034 Rennellwood Way', '', 'Pleasanton', 'CA', '94566', 50, datetime.datetime(2007, 6, 18, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Ahrens', 'Don', '', '4034 Rennellwood Way', '', 'Pleasanton', 'CA', '94566', 100, datetime.datetime(2007, 6, 21, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Akin', 'Charles', '', '10187 Sugar Creek Road', '', 'Bentonville', 'AR', '72712', 100, datetime.datetime(2007, 6, 16, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Akin', 'Mike', '', '181 Baywood Lane', '', 'Monticello', 'AR', '71655', 1500, datetime.datetime(2007, 5, 18, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Akin', 'Rebecca', '', '181 Baywood Lane', '', 'Monticello', 'AR', '71655', 500, datetime.datetime(2007, 5, 18, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aldridge', 'Brittni', '', '808 Capitol Square Place, SW', '', 'Washington', 'DC', '20024', 250, datetime.datetime(2007, 6, 6, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Allen', 'John D.', '', '1052 Cannon Mill Drive', '', 'North Augusta', 'SC', '29860', 1000, datetime.datetime(2007, 6, 11, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Allen', 'John D.', '', '1052 Cannon Mill Drive', '', 'North Augusta', 'SC', '29860', 1300, datetime.datetime(2007, 6, 29, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Allison', 'John W.', '', 'P.O. Box 1089', '', 'Conway', 'AR', '72033', 1000, datetime.datetime(2007, 5, 18, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Allison', 'Rebecca', '', '3206 Summit Court', '', 'Little Rock', 'AR', '72227', 1000, datetime.datetime(2007, 4, 25, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Allison', 'Rebecca', '', '3206 Summit Court', '', 'Little Rock', 'AR', '72227', 200, datetime.datetime(2007, 6, 12, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Altes', 'R.D.', '', '8600 Moody Road', '', 'Fort Smith', 'AR', '72903', 2300, datetime.datetime(2007, 6, 21, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Andres', 'Dale', '', '1160 Glen Oaks Drive', '', 'West Des Moines', 'IA', '50266', 250, datetime.datetime(2007, 6, 6, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Anthony', 'John', '', '211 Long Island Drive', '', 'Hot Springs', 'AR', '71913', 2300, datetime.datetime(2007, 6, 12, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Arbogast', 'Robert', '', '12900 State Route 56 SE', '', 'Mount Sterling', 'OH', '43143', 500, datetime.datetime(2007, 4, 8, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Arbogast', 'Robert', '', '12900 State Route 56 SE', '', 'Mount Sterling', 'OH', '43143', 100, datetime.datetime(2007, 6, 22, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Ardle', 'William', '', '412 Dakota Avenue', '', 'Springfield', 'OH', '45504', 50, datetime.datetime(2007, 6, 28, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Atiq', 'Omar', '', '7200 S Hazel Street', '', 'Pine Bluff', 'AR', '71603', 1000, datetime.datetime(2007, 5, 18, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Atiq', 'Omar', '', '7200 S Hazel Street', '', 'Pine Bluff', 'AR', '71603', 1000, datetime.datetime(2007, 6, 27, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Baker', 'David', '', '2550 Adamsbrooke Drive', '', 'Conway', 'AR', '72034', 2300, datetime.datetime(2007, 4, 11, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Bancroft', 'David', '', '2934 Broderick Street', '', 'San Francisco', 'CA', '94123', 250, datetime.datetime(2007, 4, 24, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Banks', 'Charles', '', 'P.O. Box 251310', '', 'Little Rock', 'AR', '72225', 1000, datetime.datetime(2007, 5, 14, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Barbee', 'John', '', '516 Kellyridge Drive', '', 'Apex', 'NC', '27502', 500, datetime.datetime(2007, 5, 23, 0, 0), 16)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Buckler', 'Steve', '', '24351 Armada Dr', '', 'Dana Point', 'CA', '926291306', 50, datetime.datetime(2007, 7, 30, 0, 0), 20)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Buckler', 'Steve', '', '24351 Armada Dr', '', 'Dana Point', 'CA', '926291306', 25, datetime.datetime(2007, 8, 16, 0, 0), 20)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Buckheit', 'Bruce', '', '8904 KAREN DR', '', 'FAIRFAX', 'VA', '220312731', 100, datetime.datetime(2007, 9, 19, 0, 0), 20)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Buckel', 'Linda', '', 'PO Box 683130', '', 'Park City', 'UT', '840683130', 2300, datetime.datetime(2007, 8, 14, 0, 0), 20)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Buckel', 'Linda', '', 'PO Box 683130', '', 'Park City', 'UT', '840683130', -2300, datetime.datetime(2007, 8, 14, 0, 0), 20)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Buckel', 'Linda', '', 'PO Box 683130', '', 'Park City', 'UT', '840683130', 4600, datetime.datetime(2007, 8, 14, 0, 0), 20)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Buck', 'Thomas', '', '4206 Terrace Street', '', 'Kansas City', 'MO', '64111', 100, datetime.datetime(2007, 9, 25, 0, 0), 20)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Buck', 'Jay', 'K.', '1855 Old Willow Rd Unit 322', '', 'Northfield', 'IL', '600932918', 200, datetime.datetime(2007, 9, 12, 0, 0), 20)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Buck', 'Blaine', 'M', '45 Eaton Ave', '', 'Camden', 'ME', '048431752', 2300, datetime.datetime(2007, 9, 30, 0, 0), 20)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Buck', 'Barbara', '', '1780 NE 138th St', '', 'North Miami', 'FL', '331811316', 50, datetime.datetime(2007, 9, 13, 0, 0), 20)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Buck', 'Barbara', '', '1780 NE 138th St', '', 'North Miami', 'FL', '331811316', 50, datetime.datetime(2007, 7, 19, 0, 0), 20)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Buchman', 'Mark M', '', '2530 Lawton Ave', '', 'San Luis Obispo', 'CA', '934015622', 460, datetime.datetime(2007, 7, 18, 0, 0), 20)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Bucher', 'Ida', 'M', '1400 Warnall Ave', '', 'Los Angeles', 'CA', '900245333', 100, datetime.datetime(2007, 7, 10, 0, 0), 20)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('

#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BURTON', 'GLENN', 'M.', '4404 CHARLESTON COURT', '', 'TAMPA', 'FL', '336092620', -2300, datetime.datetime(2008, 3, 5, 0, 0), 22)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BURKHARDT', 'CRAIG', 'S.', '910 15TH STREET N.W.', '', 'WASHINGTON', 'DC', '200052503', -500, datetime.datetime(2008, 3, 7, 0, 0), 22)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BURKHARDT', 'CRAIG', 'S.', '910 15TH STREET N.W.', '', 'WASHINGTON', 'DC', '200052503', -1000, datetime.datetime(2008, 3, 7, 0, 0), 22)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BURKHARDT', 'BARBARA', '', '910 15TH STREET N.W.', '', 'WASHINGTON', 'DC', '200052503', -500, datetime.datetime(2008, 3, 7, 0, 0), 22)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BURKE', 'SUZANNE', 'M.', '3401 EVANSTON', '', 'SEATTLE', 'WA', '981038677', -700, datetime.datetime(2008, 3, 5, 0, 0), 22)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BURKE', 'GAIL', '', '165 E. 32ND STREET', 'APARTMENT 9E', 'NEW YORK', 'NY', '100166014', -2000, datetime.datetime(2008, 3, 5, 0, 0), 22)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BURKE', 'DONALD', 'J.', '12 LOMPOC', '', 'RANCHO SANTA MARGA', 'CA', '926881817', -2300, datetime.datetime(2008, 3, 11, 0, 0), 22)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BURGERT', 'RONALD', 'L.', '5723 PLUMTREE DRIVE', '', 'DALLAS', 'TX', '752524926', -1000, datetime.datetime(2008, 3, 5, 0, 0), 22)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BULL', 'BARTLE', 'B.', '439 E. 51ST STREET', '', 'NEW YORK', 'NY', '100226473', -800, datetime.datetime(2008, 3, 10, 0, 0), 22)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BULL', 'BARTLE', 'B.', '439 E. 51ST STREET', '', 'NEW YORK', 'NY', '100226473', -1000, datetime.datetime(2008, 3, 10, 0, 0), 22)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BUKOWSKI', 'DANIEL', 'J.', '702 S. WRIGHT STREET', '', 'NAPERVILLE', 'IL', '605406736', -100, datetime.datetime(2008, 3, 10, 0, 0), 22)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BUISSON', 'MARGARET', 'A.', 'P.O. BOX 197029', '', 'LOUISVILLE', 'KY', '402597029', -200, datetime.datetime(2008, 3, 11, 0, 0), 22)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BUCKLEY', 'WALTER', 'W.', '1635 COUNTRY ROAD', '', 'BETHLEHEM', 'PA', '180155718', -100, datetime.datetime(2008, 3, 5, 0, 0), 22)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BUCKLEY', 'MARJORIE', 'B.', '1635 COUNTRY ROAD', '', 'BETHLEHEM', 'PA', '180155718', -100, datetime.datetime(2008, 3, 5, 0, 0), 22)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BRUNO', 'JOHN', '', '10136 WINDERMERE CHASE BLVD.', '', 'GOTHA', 'FL', '347344707', -2300, datetime.datetime(2008, 3, 6, 0, 0), 22)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BRUNO', 'IRENE', '', '10136 WINDERMERE CHASE BLVD.', '', 'GOTHA', 'FL', '347344707', -2300, datetime.datetime(2008, 3, 6, 0, 0), 22)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BROWN', 'TIMOTHY', 'J.', '26826 MARLOWE COURT', '', 'STEVENSON RANCH', 'CA', '913811020', -2300, datetime.datetime(2008, 3, 6, 0, 0), 22)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Schuff', 'Bryan', '', '1700 W Sweden Rd', '', 'Brockport', 'NY', '14420', -25, datetime.datetime(2008, 8, 22, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Hobbs', 'James', '', '229 Cherry Lane', '', 'White House', 'TN', '37188', -25, datetime.datetime(2008, 8, 19, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Ranganath', 'Anoop', '', '2507 Willard Drive', '', 'Charlottesville', 'VA', '22903', -100, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Nystrom', 'Michael', 'A', '93A Fairmont Street', '', 'Arlington', 'MA', '02474', -503, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Muse', 'Nina', 'Jo', '2915 Toro Canyon Rd', '', 'Austin', 'TX', '78746', -50, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Waddell', 'James', 'L.', '1823 Spel Lane SW', '', 'Rochester', 'MN', '55902', -28, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Brucks', 'William', 'C.', 'PO Box 391', '', 'Corona del Mar', 'CA', '92625', -150, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Kuehn', 'David', '', '14502 West 93rd Street', '', 'Lenexa', 'KS', '66215', -330, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Verster', 'Jeanette', 'M.', '7220 SW 61st St', '', 'Miami', 'FL', '331431807', -1000, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Uihlein', 'Richard', '', '1396 N Waukegan Rd', '', 'Lake Forest', 'IL', '600451147', -2300, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Eskenberry', 'Robert', 'P', '10960 Gray Cir', '', 'Westminster', 'CO', '80020', -223, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Froehling', 'Alan', 'L.', '302 Broadway St', '', 'Mount Vernon', 'IL', '628645116', -844, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Duryea', 'Marcia', 'A.', '123 Bayview Ave', '', 'Amityville', 'NY', '11701', -299, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Perreault', 'Louise', '', '503 Brockridge Hunt Drive', '', 'Hampton', 'VA', '23666', -34, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Rozenfeld', 'Timur', '', '57 Herbert Road', '', 'Robbinsville', 'NJ', '08691', -777, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Kazor', 'Christopher', 'M', '707 Spindletree ave', '', 'Naperville', 'IL', '60565', -2592, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Lehner', 'Thomas', 'S.', '2701 Star Lane', '', 'Wadsworth', 'OH', '44281', -200, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Plummer', 'Joseph', '', '587 Blake Hill Rd', '', 'New Hampton', 'NH', '032564424', -24, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Raught', 'Philip', 'M', '4714 Plum Way', '', 'Pittsburgh', 'PA', '15201', -1046, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Ferrara', 'Judith', 'D', '1508 Waterford Road', '', 'Yardley', 'PA', '19067', -1100, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Johnson', 'Cathleen', 'E.', '1003 Justin Ln Apt 2016', '', 'Austin', 'TX', '787572648', -14, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Sanford', 'Bradley', '', '940 Post St #43', '', 'San Francisco', 'CA', '94109', -24, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Gaarder', 'Bruce', '', 'PO Box 4085', '', 'Mountain Home AFB', 'ID', '83648', -261, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Choe', 'Hyeokchan', '', '207 Bridle Way', '', 'Fort Lee', 'NJ', '070246302', -39, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Jacobs', 'Richard', 'G.', '14337 Tawya Rd', '', 'Apple Valley', 'CA', '923075545', -1000, datetime.datetime(2008, 4, 21, 0, 0), 32)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaronson', 'Rebecca', '', '2000 Village Green Dr Apt 12', '', 'Mill Creek', 'WA', '980125787', 100, datetime.datetime(2008, 2, 8, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aarons', 'Elaine', '', '481 Buck Island Rd Apt 17A', 'APT 17A', 'West Yarmouth', 'MA', '026733300', 25, datetime.datetime(2008, 2, 26, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aarons', 'Elaine', '', '481 Buck Island Rd Apt 17A', 'APT 17A', 'West Yarmouth', 'MA', '026733300', 70, datetime.datetime(2008, 2, 25, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aarons', 'Elaine', '', '481 Buck Island Rd Apt 17A', 'APT 17A', 'West Yarmouth', 'MA', '026733300', 100, datetime.datetime(2008, 2, 8, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaron', 'Shirley', '', '101 Cherry Ave', '', 'Havana', 'FL', '323331311', 50, datetime.datetime(2008, 2, 29, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaron', 'Shirley', '', '101 Cherry Ave', '', 'Havana', 'FL', '323331311', 100, datetime.datetime(2008, 2, 29, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaronson', 'Rebecca', '', '2000 Village Green Dr Apt 12', '', 'Mill Creek', 'WA', '980125787', 100, datetime.datetime(2008, 2, 14, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaron', 'Shirley', '', '101 Cherry Ave', '', 'Havana', 'FL', '323331311', 100, datetime.datetime(2008, 2, 24, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaron', 'Shirley', '', '101 Cherry Ave', '', 'Havana', 'FL', '323331311', 100, datetime.datetime(2008, 2, 22, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaron', 'Shirley', '', '101 Cherry Ave', '', 'Havana', 'FL', '323331311', 100, datetime.datetime(2008, 2, 17, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Reid', 'Elizabeth', '', '73 W Patent Rd', 'OPHIR FARM NORTH', 'Bedford Hills', 'NY', '105072222', -350, datetime.datetime(2008, 8, 28, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Reich', 'Thomas', '', '499 Park Ave', '', 'New York', 'NY', '100221240', -2300, datetime.datetime(2008, 8, 28, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaron', 'Shirley', '', '101 Cherry Ave', '', 'Havana', 'FL', '323331311', 100, datetime.datetime(2008, 2, 8, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaron', 'Shirley', '', '101 Cherry Ave', '', 'Havana', 'FL', '323331311', 100, datetime.datetime(2008, 2, 3, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaron', 'Sharron', '', '1804 E Montgomery St', '', 'Broken Arrow', 'OK', '740121840', 500, datetime.datetime(2008, 2, 9, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaron', 'Patricia', '', '418 NW 35th St', '', 'Oklahoma City', 'OK', '731188602', 200, datetime.datetime(2008, 2, 26, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaron', 'Patricia', '', '418 NW 35th St', '', 'Oklahoma City', 'OK', '731188602', 100, datetime.datetime(2008, 2, 12, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaron', 'Jim', '', '2178 Fairway Cir', '', 'Canton', 'MI', '481885097', 300, datetime.datetime(2008, 2, 7, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaron', 'Jim', '', '2178 Fairway Cir', '', 'Canton', 'MI', '481885097', 200, datetime.datetime(2008, 2, 29, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaron', 'Carole', '', 'PO Box 1806', '', 'Ogunquit', 'ME', '039071806', 70, datetime.datetime(2008, 2, 29, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaron', 'Carole', '', 'PO Box 1806', '', 'Ogunquit', 'ME', '039071806', 50, datetime.datetime(2008, 2, 7, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaron', 'Carole', '', 'PO Box 1806', '', 'Ogunquit', 'ME', '039071806', 100, datetime.datetime(2008, 2, 3, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aaron', 'Barbara', '', '2298 Pacific Ave # 6', '', 'San Francisco', 'CA', '941151435', 1000, datetime.datetime(2008, 2, 11, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aanonsen', 'Lin', '', '897 Raymond Ave', '', 'Saint Paul', 'MN', '551141508', 250, datetime.datetime(2008, 2, 21, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('Aanonsen', 'Lin', '', '897 Raymond Ave', '', 'Saint Paul', 'MN', '551141508', 100, datetime.datetime(2008, 2, 8, 0, 0), 34)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('BOURNE', 'TRAVIS', '', 'LAGE KAART 77', '', 'BRASSCHATT', '', '02930', -500, datetime.datetime(2008, 11, 20, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('SECRIST', 'BRIAN', 'L.', '3 MULE DEER TRAIL', '', 'LITTLETON', 'CO', '801275722', -1000, datetime.datetime(2008, 4, 7, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('TOLLESTRUP', 'TRAVIS', 'W.', '16331 WINECREEK RD.', '', 'SAN DIEGO', 'CA', '92127', -1000, datetime.datetime(2008, 5, 15, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ACCORD', 'DEAN', 'C.', '8813 ROBINSON RIDGE ROAD', '', 'LAS VEGAS', 'NV', '891175812', 500, datetime.datetime(2007, 7, 13, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABTS', 'HENRY', '', 'P. O. BOX 7299', '', 'INCLINE VILLAGE', 'NV', '894527299', 100, datetime.datetime(2007, 7, 13, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABSHIER', 'LANNY', '', '14191 S.E. HIGHWAY 301', '', 'SUMMERFIELD', 'FL', '34491', 500, datetime.datetime(2007, 9, 25, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABSHIER', 'DIANA', '', '14191 S.E. HIGHWAY 301', '', 'SUMMERFIELD', 'FL', '34491', 500, datetime.datetime(2007, 9, 25, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABREU', 'KEVIN', 'M.', '1305 GARDEN GLEN LANE', '', 'PEARLAND', 'TX', '775816547', 50, datetime.datetime(2007, 9, 30, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABREU', 'KEVIN', 'M.', '1305 GARDEN GLEN LANE', '', 'PEARLAND', 'TX', '775816547', 150, datetime.datetime(2007, 8, 9, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABREU', 'KEVIN', 'M.', '1305 GARDEN GLEN LANE', '', 'PEARLAND', 'TX', '775816547', 50, datetime.datetime(2007, 7, 19, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABRAMOWITZ', 'NIRA', '', '411 HARBOR ROAD', '', 'SOUTHPORT', 'CT', '068901376', 2300, datetime.datetime(2007, 9, 14, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABRAMS', 'MICHAEL', '', '7910 WOODMONT AVENUE', '', 'BETHESDA', 'MD', '208143002', 250, datetime.datetime(2007, 9, 29, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABRAMOWITZ', 'KEN', '', '200 CENTRAL PARK S.', 'APARTMENT 31A', 'NEW YORK', 'NY', '100191448', 300, datetime.datetime(2007, 9, 11, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABOUBAKARE', 'NASAR', '', '1400 SAN MIGUEL DRIVE', '', 'CORONA DEL MAR', 'CA', '926251300', 1000, datetime.datetime(2007, 7, 9, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABEGG', 'PATRICIA', 'T.', '1862 E. 5150 S.', '', 'SALT LAKE CITY', 'UT', '841176911', 75, datetime.datetime(2007, 9, 25, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABEGG', 'PATRICIA', 'T.', '1862 E. 5150 S.', '', 'SALT LAKE CITY', 'UT', '841176911', 25, datetime.datetime(2007, 9, 17, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABEGG', 'PATRICIA', 'T.', '1862 E. 5150 S.', '', 'SALT LAKE CITY', 'UT', '841176911', 75, datetime.datetime(2007, 8, 31, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABEGG', 'PATRICIA', 'T.', '1862 E. 5150 S.', '', 'SALT LAKE CITY', 'UT', '841176911', 75, datetime.datetime(2007, 8, 14, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABEGG', 'PATRICIA', 'T.', '1862 E. 5150 S.', '', 'SALT LAKE CITY', 'UT', '841176911', 25, datetime.datetime(2007, 8, 6, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABEGG', 'PATRICIA', 'T.', '1862 E. 5150 S.', '', 'SALT LAKE CITY', 'UT', '841176911', 25, datetime.datetime(2007, 7, 10, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABDELLA', 'THOMAS', 'M.', '4231 MONUMENT WALL WAY #340', '', 'FAIRFAX', 'VA', '220308440', 50, datetime.datetime(2007, 9, 30, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABBOTT', 'WELDON', 'S.', '777 EAST SOUTH TEMPLE  4E', '', 'SALT LAKE CITY', 'UT', '841021269', 100, datetime.datetime(2007, 9, 29, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABBOTT', 'WELDON', 'S.', '777 EAST SOUTH TEMPLE  4E', '', 'SALT LAKE CITY', 'UT', '841021269', 50, datetime.datetime(2007, 8, 9, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABBOTT', 'GERALD', 'F.', '389 BENEFIT STREET', '', 'PROVIDENCE', 'RI', '029032946', 100, datetime.datetime(2007, 9, 15, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABBOTT', 'GERALD', 'F.', '389 BENEFIT STREET', '', 'PROVIDENCE', 'RI', '029032946', 100, datetime.datetime(2007, 8, 15, 0, 0), 35)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABEDIN', 'ZAINUL', '', '715 N. CENTRAL AVENUE', 'SUITE 212', 'GLENDALE', 'CA', '912031164', 500, datetime.datetime(2008, 1, 21, 0, 0), 37)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABBOTT', 'SYBIL', 'F.', '446 GAMES DRIVE', '', 'RENO', 'NV', '895093326', 75, datetime.datetime(2008, 1, 8, 0, 0), 37)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABBOTT', 'SYBIL', 'F.', '446 GAMES DRIVE', '', 'RENO', 'NV', '895093326', 50, datetime.datetime(2008, 1, 8, 0, 0), 37)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABBOTT', 'RONALD', 'LEANDER', '5453 HAWTHORNE STREET', '', 'MONTCLAIR', 'CA', '917632551', 200, datetime.datetime(2008, 1, 31, 0, 0), 37)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('

#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABRAHAM', 'SALEM', 'A.', 'P.O. BOX 7', '', 'CANADIAN', 'TX', '790140007', 1000, datetime.datetime(2008, 1, 17, 0, 0), 37)
#
# INSERT INTO contributors (last_name, first_name, middle_name, street_1, street_2, city, state, zip, amount, date, candidate_id)     VALUES (?,?,?,?,?, ?, ?, ?, ?, ?, ?);
#  ('ABRAHAM', 'SALEM', 'A.', 'P.O. BOX 7', '', 'CANADIAN', 'TX', '790140007', 1300, datetime.datetime(2008, 1, 30, 0, 0), 37)
# /var/folders/td/94qngg4x2_lcb32n6td6t7540000gn/T/ipykernel_7077/125978452.py:11: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   db.cursor().execute(ins, valstoinsert)

# %%
out=make_query("SELECT * FROM contributors WHERE state IN ('VA', 'MA');")
make_frame(out, legend=contributor_cols)
# Out:
#      id  last_name first_name middle_name                     street_1  \
# 0   526       Agee     Steven                   549 Laurel Branch Road
# 1   553   Buckheit      Bruce                            8904 KAREN DR
# 2   603  Ranganath      Anoop                       2507 Willard Drive
# 3   604    Nystrom    Michael           A          93A Fairmont Street
# 4   614  Perreault     Louise                503 Brockridge Hunt Drive
# 5   627     Aarons     Elaine               481 Buck Island Rd Apt 17A
# 6   628     Aarons     Elaine               481 Buck Island Rd Apt 17A
# 7   629     Aarons     Elaine               481 Buck Island Rd Apt 17A
# 8   671    ABDELLA     THOMAS          M.  4231 MONUMENT WALL WAY #340
# 9   683      ABBOT      DAVID          M.              56 SALEM STREET
# 10  686      ABAIR      PETER                          40 EVANS STREET
#
#    street_2             city state        zip  amount                 date  \
# 0                      Floyd    VA      24091     500  2007-06-30 00:00:00
# 1                    FAIRFAX    VA  220312731     100  2007-09-19 00:00:00
# 2            Charlottesville    VA      22903    -100  2008-04-21 00:00:00
# 3                  Arlington    MA      02474    -503  2008-04-21 00:00:00
# 4                    Hampton    VA      23666     -34  2008-04-21 00:00:00
# 5   APT 17A    West Yarmouth    MA  026733300      25  2008-02-26 00:00:00
# 6   APT 17A    West Yarmouth    MA  026733300      70  2008-02-25 00:00:00
# 7   APT 17A    West Yarmouth    MA  026733300     100  2008-02-08 00:00:00
# 8                    FAIRFAX    VA  220308440      50  2007-09-30 00:00:00
# 9                    ANDOVER    MA  018102114     200  2008-01-21 00:00:00
# 10                 WATERTOWN    MA  024722150      25  2008-01-09 00:00:00
#
#     candidate_id
# 0             16
# 1             20
# 2             32
# 3             32
# 4             32
# 5             34
# 6             34
# 7             34
# 8             35
# 9             37
# 10            37

# %%
q = make_query("select * from contributors where last_name = 'ABREU';")
make_frame(q, contributor_cols)
# Out:
#     id last_name first_name middle_name               street_1 street_2  \
# 0  658     ABREU      KEVIN          M.  1305 GARDEN GLEN LANE
# 1  659     ABREU      KEVIN          M.  1305 GARDEN GLEN LANE
# 2  660     ABREU      KEVIN          M.  1305 GARDEN GLEN LANE
#
#        city state        zip  amount                 date  candidate_id
# 0  PEARLAND    TX  775816547      50  2007-09-30 00:00:00            35
# 1  PEARLAND    TX  775816547     150  2007-08-09 00:00:00            35
# 2  PEARLAND    TX  775816547      50  2007-07-19 00:00:00            35

# %% [markdown]
# This is obviously the same dude so next time we need to clean this up so that our database does not have reprting individuals under one contributor.
